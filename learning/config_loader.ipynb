# %%
from backtester.config.config_loader import ConfigLoader

# %%
loader = ConfigLoader(base_dir="../backtester/config")

# %%
loader.load("sma.toml")
# Out:
# {'data': {'source': 'csv',
#   'path': './data/eurusd.csv',
#   'symbol': 'EURUSD',
#   'timeframe': '1h'},
#  'strategy': {'name': 'sma50_200',
#   'kind': 'sma_cross',
#   'params': {'fast': 50, 'slow': 200},
#   'cash': 150000,
#   'start': datetime.date(2023, 1, 1),
#   'end': datetime.date(2024, 12, 31),
#   'commission_bps': 0.5,
#   'slippage_bps': 0.2,
#   'seed': 123,
#   'results_dir': './runs'}}
